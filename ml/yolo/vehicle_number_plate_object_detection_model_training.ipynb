# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

# %%
cd /content/drive/MyDrive/ColabNotebooks/vehicle_number_plate_object_detection_correct

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 722.1/722.1 kB 16.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 66.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 69.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 99.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 2.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 2.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 8.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 15.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 8.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 2.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.0/166.0 MB 7.1 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
import os
from IPython.display import display, Image
from IPython import display
display.clear_output()
# !yolo checks
# Out:
# Ultralytics YOLOv8.1.31 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 28.9/78.2 GB disk)
#
# OS                  Linux-6.1.58+-x86_64-with-glibc2.35
# Environment         Colab
# Python              3.10.12
# Install             pip
# RAM                 12.67 GB
# CPU                 Intel Xeon 2.20GHz
# CUDA                12.1
#
# matplotlib          ✅ 3.7.1>=3.3.0
# opencv-python       ✅ 4.8.0.76>=4.6.0
# pillow              ✅ 9.4.0>=7.1.2
# pyyaml              ✅ 6.0.1>=5.3.1
# requests            ✅ 2.31.0>=2.23.0
# scipy               ✅ 1.11.4>=1.4.1
# torch               ✅ 2.2.1+cu121>=1.8.0
# torchvision         ✅ 0.17.1+cu121>=0.9.0
# tqdm                ✅ 4.66.2>=4.64.0
# psutil              ✅ 5.9.5
# py-cpuinfo          ✅ 9.0.0
# thop                ✅ 0.1.1-2209072238>=0.1.1
# pandas              ✅ 1.5.3>=1.1.4
# seaborn             ✅ 0.13.1>=0.11.0

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="aPu216DUrx5eGUwyZTEv")
project = rf.workspace("matheus-santos-almeida").project("car_license_plate")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.9/71.9 kB 2.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.3/158.3 kB 14.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 27.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 9.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.1/49.1 MB 11.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 8.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.9.0.80
#     Uninstalling opencv-python-headless-4.9.0.80:
#       Successfully uninstalled opencv-python-headless-4.9.0.80
#   Attempting uninstall: idna
#     Found existing installation: idna 3.6
#     Uninstalling idna-3.6:
#       Successfully uninstalled idna-3.6
#   Attempting uninstall: cycler
#     Found existing installation: cycler 0.12.1
#     Uninstalling cycler-0.12.1:
# ...

# %%
# !pwd
# Out:
# /content/drive/MyDrive/ColabNotebooks/vehicle_number_plate_object_detection_correct

# %%
from ultralytics import YOLO

# Load a model
model = YOLO('yolov8n.yaml')  # build a new model from YAML
model = YOLO('yolov8n.pt')  # load a pretrained model (recommended for training)
model = YOLO('yolov8n.yaml').load('yolov8n.pt')  # build from YAML and transfer weights

# Train the model
#pass save_dir argument to change save location
results = model.train(data='./car_license_plate-1/data.yaml', epochs=100, imgsz=640)
# Out:
# ...
# 100%|██████████| 6.23M/6.23M [00:00<00:00, 163MB/s]
# Transferred 355/355 items from pretrained weights
# Ultralytics YOLOv8.1.31 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !pwd
# Out:
# /content/drive/MyDrive/ColabNotebooks/vehicle_number_plate_object_detection_correct

# %%
from ultralytics import YOLO

# Load a model
model = YOLO('./runs/detect/train/weights/best.pt')

# Customize validation settings
validation_results = model.val(data='./car_license_plate-1/data.yaml',
                               imgsz=640,
                               batch=16,
                               conf=0.25,
                               iou=0.6,
                               device='0')
# Out:
# Ultralytics YOLOv8.1.31 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
# ...
# 100%|██████████| 755k/755k [00:00<00:00, 119MB/s]
# val: Scanning /content/drive/MyDrive/ColabNotebooks/vehicle_number_plate_object_detection_correct/car_license_plate-1/valid/labels.cache... 60 images, 0 backgrounds, 0 corrupt: 100%|██████████| 60/60 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 4/4 [00:25<00:00,  6.32s/it]
#                    all         60         64      0.783      0.844       0.87      0.542
# Speed: 4.8ms preprocess, 19.1ms inference, 0.0ms loss, 20.6ms postprocess per image
# Results saved to runs/detect/val

# %%
import os
import glob

def get_image_paths(directory):
    extensions = ['*.jpg', '*.jpeg', '*.png', '*.gif', '*.bmp']
    image_paths = []

    for ext in extensions:
        image_paths.extend(glob.glob(os.path.join(directory, ext)))

    return image_paths

# Usage
directory = './car_license_plate-1/test/images'
image_paths = get_image_paths(directory)

print(image_paths)
# Out:
# ['./car_license_plate-1/test/images/Cars100_png.rf.59ab65fb1cd60b07568305c878ab6b58.jpg', './car_license_plate-1/test/images/Cars103_png.rf.c1396fe10252ededea5f35d8e83fb890.jpg', './car_license_plate-1/test/images/Cars112_png.rf.6b7577d9914980079f0761451ffe5b40.jpg', './car_license_plate-1/test/images/Cars175_png.rf.72f493b8203402b36fd1b4f352f4aad9.jpg', './car_license_plate-1/test/images/Cars176_png.rf.695b57c7eed67dd6807e5c1f957e38b4.jpg', './car_license_plate-1/test/images/Cars188_png.rf.e985dda16f6c6af06b65a429bd7f8624.jpg', './car_license_plate-1/test/images/Cars196_png.rf.e496c2b81c46e5242a5d6320eca31412.jpg', './car_license_plate-1/test/images/Cars205_png.rf.4ec46820cc1dae0a9559fa87cc5d1d7d.jpg', './car_license_plate-1/test/images/Cars209_png.rf.632ed28501e65139a22004b577847a80.jpg', './car_license_plate-1/test/images/Cars219_png.rf.b59a6d384d12a2c69a39f71e37a3318d.jpg', './car_license_plate-1/test/images/Cars229_png.rf.f36d0ca1a47e178f5d8a3894df28f355.jpg', './car_license_pla
# ...

# %%
from ultralytics import YOLO

# Load a model
model = YOLO('./runs/detect/train/weights/best.pt')  # pretrained YOLOv8n model

# Run batched inference on a list of images
results = model(image_paths, stream=True)  # return a generator of Results objects

count = 0

# Process results generator
for result in results:
    boxes = result.boxes  # Boxes object for bounding box outputs
    masks = result.masks  # Masks object for segmentation masks outputs
    keypoints = result.keypoints  # Keypoints object for pose outputs
    probs = result.probs  # Probs object for classification outputs
    result.show()  # display to screen
    result.save(filename='./runs/detect/predict/' + image_paths[count].split("/")[4] + '.jpg')  # save to disk
    count+=1
# Out:
# 0: 640x640 (no detections), 4.2ms
# 1: 640x640 1 licence, 4.2ms
# 2: 640x640 1 licence, 4.2ms
# 3: 640x640 (no detections), 4.2ms
# 4: 640x640 1 licence, 4.2ms
# 5: 640x640 (no detections), 4.2ms
# 6: 640x640 (no detections), 4.2ms
# 7: 640x640 1 licence, 4.2ms
# 8: 640x640 1 licence, 4.2ms
# 9: 640x640 1 licence, 4.2ms
# 10: 640x640 1 licence, 4.2ms
# 11: 640x640 1 licence, 4.2ms
# 12: 640x640 1 licence, 4.2ms
# 13: 640x640 2 licences, 4.2ms
# 14: 640x640 (no detections), 4.2ms
# 15: 640x640 1 licence, 4.2ms
# 16: 640x640 1 licence, 4.2ms
# 17: 640x640 1 licence, 4.2ms
# 18: 640x640 1 licence, 4.2ms
# 19: 640x640 1 licence, 4.2ms
# 20: 640x640 1 licence, 4.2ms
# 21: 640x640 1 licence, 4.2ms
# 22: 640x640 1 licence, 4.2ms
# 23: 640x640 1 licence, 4.2ms
# 24: 640x640 2 licences, 4.2ms
# 25: 640x640 1 licence, 4.2ms
# 26: 640x640 2 licences, 4.2ms
# 27: 640x640 1 licence, 4.2ms
# 28: 640x640 1 licence, 4.2ms
# 29: 640x640 1 licence, 4.2ms
# ...

# %%
# import time
# for i in range(1, 10000000000000000000, 1):
#   print(i, end="")
#   time.sleep(1)
#   # break
